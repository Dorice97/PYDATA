# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import gaussian_kde

# %%
url = r"C:\Users\dorice asami\Desktop\pydata\panda\commodity_futures.csv"
commodity = pd.read_csv(url)

# %%
commodity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6092 entries, 0 to 6091
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6092 non-null   object
#  1   NATURAL GAS          6083 non-null   float64
#  2   GOLD                 6082 non-null   float64
#  3   WTI CRUDE            6083 non-null   float64
#  4   BRENT CRUDE          6090 non-null   float64
#  5   SOYBEANS             6083 non-null   float64
#  6   CORN                 6084 non-null   float64
#  7   COPPER               6083 non-null   float64
#  8   SILVER               6079 non-null   float64
#  9   LOW SULPHUR GAS OIL  6090 non-null   float64
#  10  LIVE CATTLE          6084 non-null   float64
#  11  SOYBEAN OIL          6079 non-null   float64
#  12  ALUMINIUM            6045 non-null   float64
#  13  SOYBEAN MEAL         6082 non-null   float64
#  14  ZINC                 6046 non-null   float64
# ...

# %%
commodity.head()
# Out:
#          Date  NATURAL GAS   GOLD  WTI CRUDE  BRENT CRUDE  SOYBEANS    CORN  \
# 0  2000-01-03          NaN    NaN        NaN          NaN    456.50  200.75
# 1  2000-01-04        2.176  283.7      25.55        24.39    464.25  203.00
# 2  2000-01-05        2.168  282.1      24.91        23.73    469.25  203.00
# 3  2000-01-06        2.196  282.4      24.78        23.62    468.00  203.75
# 4  2000-01-07        2.173  282.9      24.22        23.09    471.50  207.00
#
#    COPPER  SILVER  LOW SULPHUR GAS OIL  ...     ZINC  ULS DIESEL  NICKEL  \
# 0     NaN     NaN                  NaN  ...  1237.50         NaN  8446.0
# 1  0.8480   5.375               213.50  ...  1215.00       67.78  8314.0
# 2  0.8565   5.210               213.00  ...  1209.25       66.55  8307.0
# 3  0.8530   5.167               211.25  ...  1212.00       66.28  8252.0
# 4  0.8540   5.195               205.25  ...  1209.25       64.75  8174.0
#
#     WHEAT  SUGAR  GASOLINE  COFFEE  LEAN HOGS  HRW WHEAT  COTTON
# ...

# %%
plt.figure(figsize=(8,5))

# %%
axes= = fig.add_axes([0.1,0.1,0.8,0.8],)

# %%
commodity["date"]=pd.to_datetime(commodity["Date"],format='mixed')

# %%
commodity['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
commodity.columns
# Out:
# Index(['Date', 'NATURAL GAS', 'GOLD', 'WTI CRUDE', 'BRENT CRUDE', 'SOYBEANS',
#        'CORN', 'COPPER', 'SILVER', 'LOW SULPHUR GAS OIL', 'LIVE CATTLE',
#        'SOYBEAN OIL', 'ALUMINIUM', 'SOYBEAN MEAL', 'ZINC', 'ULS DIESEL',
#        'NICKEL', 'WHEAT', 'SUGAR', 'GASOLINE', 'COFFEE', 'LEAN HOGS',
#        'HRW WHEAT', 'COTTON', 'date'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))

plt.plot(commodity['Date'],commodity['GOLD'])

plt.show()

# %%
fig, ax= plt.subplots(1,2,figsize=(16,4))
ax[0].plot(commodity['Date'],commodity['GOLD'])
ax[1].plot(commodity['Date'],commodity['ALUMINIUM'])
plot.show()

# %%
#line plot
plt.figure(figsize=(12,6))

plt.plot(commodity['Date'],commodity['GOLD'])

plt.show()

# %%
plt.figure(figsize=(12,6))
x=commodity['Date']
y=commodity['GOLD']
z=commodity['ALUMINIUM']
plt.plot(x,y,label="GOLD")
plt.plot(x,y,label="ALUMINIUM")
plt.plot(x,y)
plt.title("GOLD Prices over time",fontdict={'fontsize':12,'fontweight':'bold'})
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(12,4))
x=commodity['Date']
y=commodity['GOLD']
z=commodity['ALUMINIUM']
ax[0].plot(x,y,color='beige',label='GOLD')
ax[1].plot(x,y,color='maroon',label='aluminium')
ax[0].legend()
ax[1].legend()
ax[0].set_title('Gold over time')
ax[1].set_title('Aluminium over time')
ax[0].set_xlabel('Date')
ax[1].set_xlabel('Date')
ax[0].set_ylabel('Gold prices')
ax[1].set_ylabel('Aluminium prices')

plt.show()

# %%
url = r"C:\Users\dorice asami\Desktop\pydata\panda\quantium_merged_data (1).csv"
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246740 entries, 0 to 246739
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        246740 non-null  int64
#  1   LYLTY_CARD_NBR    246740 non-null  int64
#  2   DATE              246740 non-null  object
#  3   STORE_NBR         246740 non-null  int64
#  4   TXN_ID            246740 non-null  int64
#  5   PROD_NBR          246740 non-null  int64
#  6   PROD_NAME         246740 non-null  object
#  7   PROD_QTY          246740 non-null  int64
#  8   TOT_SALES         246740 non-null  float64
#  9   BRAND             246740 non-null  object
#  10  PACKET_SIZE       246740 non-null  int64
#  11  LIFESTAGE         246740 non-null  object
#  12  PREMIUM_CUSTOMER  246740 non-null  object
#  13  ext_names         246740 non-null  object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 26.4+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0           0            1000  2018-10-17          1       1         5
# 1           1            1002  2018-09-16          1       2        58
# 2           2            1003  2019-03-07          1       3        52
# 3           3            1003  2019-03-08          1       4       106
# 4           4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES       BRAND  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0     Natural
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7         RRD
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6     GrnWves
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0     Natural
# 4          WW Original Stacked Chips 160g         1        1.9  Woolworths
#
#    PACKET_SIZE              LIFESTAGE PREMIUM_CUSTOMER  \
# ...

# %%
#check number of unique brands
df["BRAND"].unique()
# Out:
# array(['Natural', 'RRD', 'GrnWves', 'Woolworths', 'Cheetos', 'Infuzions',
#        'Doritos', 'Smiths', 'Kettle', 'CCs', 'Tostitos', 'Cobs', 'Burger',
#        'Thins', 'Tyrrells', 'Cheezels', 'Twisties', 'Sunbites',
#        'Pringles', 'French'], dtype=object)

# %%
df["BRAND"].nunique()
# Out:
# 20

# %%
Brand_sales= df.groupby("BRAND")[['TOT_SALES']].sum().reset_index().sort_values(by="TOT_SALES",ascending=False)
print(Brand_sales)
# Out:
#          BRAND  TOT_SALES
# 9       Kettle   390239.8
# 5      Doritos   226329.9
# 13      Smiths   217492.0
# 11    Pringles   177655.5
# 8    Infuzions    99047.6
# 15       Thins    88852.5
# 12         RRD    87607.5
# 17    Twisties    81522.1
# 16    Tostitos    79789.6
# 4         Cobs    70569.8
# 18    Tyrrells    51647.4
# 7      GrnWves    51617.2
# 10     Natural    42318.0
# 19  Woolworths    41059.1
# 3     Cheezels    40029.9
# 1          CCs    18078.9
# 2      Cheetos    16884.5
# 14    Sunbites     9676.4
# 6       French     7929.0
# 0       Burger     6831.0

# %%
plt.figure(figsize=(15,6))

plt.bar(Brand_sales['BRAND'],Brand_sales['TOT_SALES'])
plt.show()
